# %%
# Author and date
import datetime, getpass
user = getpass.getuser()
print(user, datetime.datetime.today())
# Out:
# ubuntu 2020-04-26 19:57:31.235492

# %%
# %matplotlib inline
from ipywidgets import Image
from matplotlib import pyplot as plt

import datajoint as dj

# %%
schema = dj.schema(f'cinni_states')
# Out:
# Connecting cinni@db.data-science-ust.net:3306

# %%
# Some useful links and their format
#http://www.theus50.com/images/state-licenses/texas-license.jpg
#http://www.theus50.com/images/state-birds/texas-bird.jpg
#http://www.theus50.com/images/state-stamps/texas-stamp.jpg

# %%
states = dict(
    AL='Alabama',        AK='Alaska',       AZ='Arizona',      AR='Arkansas',
    CA='California',     CO='Colorado',     CT='Connecticut',  DE='Delaware',
    FL='Florida',        GA='Georgia',      HI='Hawaii',       ID='Idaho', 
    IL='Illinois',       IN='Indiana',      IA='Iowa',         KS='Kansas',
    KY='Kentucky',       LA='Louisiana',    ME='Maine',        MD='Maryland',
    MA='Massachusetts',  MI='Michigan',     MN='Minnesota',    MS='Mississippi',
    MO='Missouri',       MT='Montana',      NE='Nebraska',     NV='Nevada',
    NH='New Hampshire',  NJ='New Jersey',   NM='New Mexico',   NY='New York',
    NC='North Carolina', ND='North Dakota', OH='Ohio',         OK='Oklahoma',
    OR='Oregon',         PA='Pennsylvania', RI='Rhode Island', SC='South Carolina',
    SD='South Dakota',   TN='Tennessee',    TX='Texas',        UT='Utah',
    VT='Vermont',        VA='Virginia',     WA='Washington',   WV='West Virginia', 
    WI='Wisconsin',      WY='Wyoming')

# %%
@schema
class State(dj.Lookup):
    definition = """
    # United States
    state_code : char(2)
    ---
    state : varchar(20)
    """
    contents = states.items()

# %%
State()
# Out:
# *state_code    state
# +------------+ +------------+
# AK             Alaska
# AL             Alabama
# AR             Arkansas
# AZ             Arizona
# CA             California
# CO             Colorado
# CT             Connecticut
# DE             Delaware
# FL             Florida
# GA             Georgia
# HI             Hawaii
# IA             Iowa
#    ...
#  (Total: 50)

# %%
form = {'state': 'texas'}
Image.from_url("http://www.theus50.com/images/state-birds/{state}-bird.jpg".format(**form))
# Out:
# Image(value=b'http://www.theus50.com/images/state-birds/texas-bird.jpg', format='url')

# %%
Image.from_url("http://www.theus50.com/images/state-flags/{state}-flag.jpg".format(**form))
# Out:
# Image(value=b'http://www.theus50.com/images/state-flags/texas-flag.jpg', format='url')

# %%
Image.from_url("http://www.theus50.com/images/state-flowers/{state}-flower.jpg".format(**form))
# Out:
# Image(value=b'http://www.theus50.com/images/state-flowers/texas-flower.jpg', format='url')

# %%
import requests

@schema
class StateBird(dj.Imported):
    definition = """
    -> State
    ---
    bird_image : longblob    
    """
    
    url_template = "http://www.theus50.com/images/state-birds/{state}-bird.jpg"
    
    def make(self, key):
        state = (State & key).fetch1('state')
        url = self.url_template.format(state=state.lower().replace(' ', ''))
        temp_file = 'tmp.jpg'
        with open(temp_file, 'wb') as f:
            f.write(requests.get(url).content)
        self.insert1(dict(key, bird_image=plt.imread(temp_file)))
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.25.9) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
StateBird().populate(display_progress=True, suppress_errors=True)
# Out:
# 0it [00:00, ?it/s]
# []

# %%
StateBird()
# Out:
# *state_code    bird_image
# +------------+ +--------+
# AK             =BLOB=
# AL             =BLOB=
# AR             =BLOB=
# AZ             =BLOB=
# CA             =BLOB=
# CO             =BLOB=
# CT             =BLOB=
# DE             =BLOB=
# FL             =BLOB=
# GA             =BLOB=
# HI             =BLOB=
# IA             =BLOB=
#    ...
#  (Total: 50)

# %%
dj.Diagram(schema)

# %%
#(State & {'state_code': 'TX'}).delete()

# %%
fig, axx = plt.subplots(5, 10, figsize=(16, 7))

for ax, info in zip(axx.flatten(), 
                    (StateBird*State).fetch(as_dict=True)):
    ax.imshow(info['bird_image'])
    ax.set_title(info['state'])
    ax.axis(False)

# %%
import requests

@schema
class StateFlag(dj.Imported):
    definition = """
    -> State
    ---
    flag_image : longblob    
    """
    
    url_template = "http://www.theus50.com/images/state-flags/{state}-flag.jpg"
    
    def make(self, key):
        state = (State & key).fetch1('state')
        url = self.url_template.format(state=state.lower().replace(' ', ''))
        temp_file = 'tmp.jpg'
        with open(temp_file, 'wb') as f:
            f.write(requests.get(url).content)
        self.insert1(dict(key, flag_image=plt.imread(temp_file)))

# %%
StateFlag.populate(display_progress=True)
# Out:
# 0it [00:00, ?it/s]

# %%
fig, axx = plt.subplots(5, 10, figsize=(16, 7))

for ax, info in zip(axx.flatten(), 
                    (StateFlag*State).fetch(as_dict=True)):
    ax.imshow(info['flag_image'])
    ax.set_title(info['state'])
    ax.axis(False)

# %%
import colorsys
@schema
class StateFlagHSV(dj.Computed):
    definition = """
    -> StateFlag
    ---
    hue : float
    sat : float
    value : float
    """
    
    def make(self, key):
        img = (StateFlag & key).fetch1('flag_image')
        hue, sat, value = colorsys.rgb_to_hsv(*img.mean(axis=(0,1))/255)
        self.insert1(dict(key, hue=hue, sat=sat, value=value))

# %%
StateFlagHSV.populate()

# %%
StateFlagHSV()
# Out:
# *state_code    hue            sat          value
# +------------+ +------------+ +----------+ +----------+
# AK             0.667975       0.95965      0.492917
# AL             0.96966        0.276514     0.886675
# AR             0.930848       0.598425     0.63129
# AZ             0.00390558     0.403959     0.418169
# CA             0.0284273      0.197031     0.835503
# CO             0.709041       0.251084     0.476023
# CT             0.588196       0.794118     0.828125
# DE             0.57916        0.595042     0.618528
# FL             0.0177658      0.35568      0.926329
# GA             0.9306         0.568943     0.585579
# HI             0.923115       0.40854      0.671578
# IA             0.875498       0.227855     0.651296
#    ...
#  (Total: 50)

# %%
fig, axx = plt.subplots(5, 10, figsize=(16, 7))

for ax, info in zip(axx.flatten(), 
                    (StateFlag*State*StateFlagHSV).fetch(as_dict=True, order_by='hue')):
    ax.imshow(info['flag_image'])
    ax.set_title(info['state'])
    ax.axis(False)

# %%
fig, axx = plt.subplots(1, 6, figsize=(16, 7))
figBird, axxBird = plt.subplots(1, 6, figsize=(16, 7))

for ax, info in zip(axx.flatten(),                    
                    (StateFlag*State*StateFlagHSV*StateBird) & 'hue>=0.9'):                    
    ax.imshow(info['flag_image'])
    ax.set_title(info['state'])
    ax.axis(False)
              
for ax, info in zip(axxBird.flatten(),                     
                    (StateFlag*State*StateFlagHSV*StateBird) & 'hue>=0.9'):                    
    ax.imshow(info['bird_image'])    
    ax.axis(False)

# %%
fig, axx = plt.subplots(1, 4, figsize=(16, 7))
figBird, axxBird = plt.subplots(1, 4, figsize=(16, 7))
for ax, info in zip(axx.flatten(), 
                    #(StateFlag*State*StateFlagHSV).fetch(as_dict=True, order_by='hue')):
                    (StateFlag*State*StateFlagHSV) & 'sat>=0.9'):                    
    ax.imshow(info['flag_image'])
    ax.set_title(info['state'])
    ax.axis(False)
for ax, info in zip(axxBird.flatten(),                     
                    (StateFlag*State*StateFlagHSV*StateBird) & 'sat>=0.9'):                    
    ax.imshow(info['bird_image'])    
    ax.axis(False)

# %%
fig, axx = plt.subplots(1, 6, figsize=(16, 7))
figBird, axxBird = plt.subplots(1, 6, figsize=(16, 7))

for ax, info in zip(axx.flatten(), 
                    #(StateFlag*State*StateFlagHSV).fetch(as_dict=True, order_by='hue')):
                    (StateFlag*State*StateFlagHSV) & 'value>=0.9'):                    
    ax.imshow(info['flag_image'])
    ax.set_title(info['state'])
    ax.axis(False)
              
for ax, info in zip(axxBird.flatten(),                     
                    (StateFlag*State*StateFlagHSV*StateBird) & 'value>=0.9'):                    
    ax.imshow(info['bird_image'])    
    ax.axis(False)

# %%
import requests

@schema
class StateLicense(dj.Imported):
    definition = """
    -> State
    ---
    license_image : longblob    
    """
    
    url_template = "http://www.theus50.com/images/state-licenses/{state}-license.jpg"
    
    def make(self, key):
        state = (State & key).fetch1('state')
        url = self.url_template.format(state=state.lower().replace(' ', ''))
        temp_file = 'tmp.jpg'
        with open(temp_file, 'wb') as f:
            f.write(requests.get(url).content)
        self.insert1(dict(key, license_image=plt.imread(temp_file)))

# %%
StateLicense().populate(display_progress=True, suppress_errors=True)
# Out:
# 100%|██████████| 50/50 [00:08<00:00,  6.19it/s]
# []

# %%
StateLicense()
# Out:
# *state_code    license_im
# +------------+ +--------+
# AK             =BLOB=
# AL             =BLOB=
# AR             =BLOB=
# AZ             =BLOB=
# CA             =BLOB=
# CO             =BLOB=
# CT             =BLOB=
# DE             =BLOB=
# FL             =BLOB=
# GA             =BLOB=
# HI             =BLOB=
# IA             =BLOB=
#    ...
#  (Total: 50)

# %%
dj.Diagram(schema)

# %%
fig, axx = plt.subplots(5, 10, figsize=(16, 7))

for ax, info in zip(axx.flatten(), 
                    (StateLicense*State).fetch(as_dict=True)):
    ax.imshow(info['license_image'])
    ax.set_title(info['state'])
    ax.axis(False)

# %%
fig, axx = plt.subplots(1, 6, figsize=(16, 7))
figBird, axxBird = plt.subplots(1, 6, figsize=(16, 7))
figLicense, axxLicense = plt.subplots(1, 6, figsize=(16, 7))

for ax, info in zip(axx.flatten(),                    
                    (StateFlag*State*StateFlagHSV*StateBird) & 'hue>=0.9'):                    
    ax.imshow(info['flag_image'])
    ax.set_title(info['state'])
    ax.axis(False)
for ax, info in zip(axxLicense.flatten(),                     
                    (StateFlag*State*StateFlagHSV*StateLicense) & 'hue>=0.9'):                    
    ax.imshow(info['license_image'])    
    ax.axis(False)
for ax, info in zip(axxBird.flatten(),                     
                    (StateFlag*State*StateFlagHSV*StateBird) & 'hue>=0.9'):                    
    ax.imshow(info['bird_image'])    
    ax.axis(False)
